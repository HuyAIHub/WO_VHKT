# %%
import pandas as pd
import numpy
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score #đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error #đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error #đo % sai số tuyệt đối trung bình

# %%
df = pd.read_csv('kpi_vhkt.csv')

# %%
df.rename(columns = {'sum_duration':'total_duration'}, inplace = True)
df
# Out:
#             date   phong_ban  total_duration
# 0     2020-01-01  wo_co_dien        59856.56
# 1     2020-01-01   wo_others          308.45
# 2     2020-01-01     wo_ksnn          682.55
# 3     2020-01-01      wo_noc         1825.36
# 4     2020-01-02      wo_noc         4725.20
# ...          ...         ...             ...
# 7805  2023-12-30      wo_noc         9872.19
# 7806  2023-12-31   wo_others        24601.24
# 7807  2023-12-31      wo_noc         9844.20
# 7808  2023-12-31     wo_ksnn        57173.30
# 7809  2023-12-31  wo_co_dien          342.89
#
# [7810 rows x 3 columns]

# %%
# Check for duplicate rows
duplicate_rows = df[df.duplicated()]

# Print duplicate rows
print("Duplicate Rows:")
print(duplicate_rows)
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [date, phong_ban, total_duration]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#             date   phong_ban  total_duration
# 0     2020-01-01  wo_co_dien        59856.56
# 1     2020-01-01   wo_others          308.45
# 2     2020-01-01     wo_ksnn          682.55
# 3     2020-01-01      wo_noc         1825.36
# 4     2020-01-02      wo_noc         4725.20
# ...          ...         ...             ...
# 7805  2023-12-30      wo_noc         9872.19
# 7806  2023-12-31   wo_others        24601.24
# 7807  2023-12-31      wo_noc         9844.20
# 7808  2023-12-31     wo_ksnn        57173.30
# 7809  2023-12-31  wo_co_dien          342.89
#
# [7810 rows x 3 columns]

# %%
# @title date vs total_duration

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['date']
  ys = series['total_duration']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('date', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('phong_ban')):
  _plot_series(series, series_name, i)
  fig.legend(title='phong_ban', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('date')
_ = plt.ylabel('total_duration')

# %%
# @title phong_ban

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('phong_ban').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# #Convert the date column to Y/M/D

# %%
#mô tả bộ dữ liệu
df.describe()
# Out:
#        total_duration
# count     7810.000000
# mean     61336.775015
# std      80243.622783
# min          0.200000
# 25%       2973.192500
# 50%      24363.355000
# 75%      94069.305000
# max     423854.490000

# %% [markdown]
# + Độ lệch chuẩn (standard deviation): Độ lệch chuẩn của total_duration là khoảng 47576.94. Điều này cho thấy sự biến động lớn giữa các giá trị của dữ liệu.
#
# Dựa trên các chỉ số này, chúng ta có thể hiểu rằng dữ liệu có phân phối rộng và đa dạng, với sự biến động lớn giữa các giá trị. Có một số mẫu có thời lượng rất ngắn và rất dài, trong khi phần lớn dữ liệu nằm ở các giá trị trung bình.

# %% [markdown]
# # Preprocessing data

# %% [markdown]
# ## Sort by date

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Sắp xếp lại dữ liệu theo thứ tự thời gian
df = df.sort_values(by='date')
df
# Out:
#             date   phong_ban  total_duration
# 0     2020-01-01  wo_co_dien        59856.56
# 1     2020-01-01   wo_others          308.45
# 2     2020-01-01     wo_ksnn          682.55
# 3     2020-01-01      wo_noc         1825.36
# 4     2020-01-02      wo_noc         4725.20
# ...          ...         ...             ...
# 7803  2023-12-30     wo_ksnn        62641.27
# 7807  2023-12-31      wo_noc         9844.20
# 7808  2023-12-31     wo_ksnn        57173.30
# 7806  2023-12-31   wo_others        24601.24
# 7809  2023-12-31  wo_co_dien          342.89
#
# [7810 rows x 3 columns]

# %% [markdown]
# # Split data into Phong Ban

# %%
df = pd.DataFrame(df)

# Tạo các nhóm dựa trên phòng ban
grouped = df.groupby('phong_ban')
# Hiển thị các nhóm
for name, group in grouped:
    print("Phòng ban:", name)
    print(group)
# Tạo một từ điển để lưu trữ các DataFrame của từng phòng ban
phong_ban_dict = {}
# Tạo các DataFrame cho từng phòng ban và lưu vào từ điển
for name, group in df.groupby('phong_ban'):
    phong_ban_dict[name] = group
# Out:
# Phòng ban: wo_co_dien
#             date   phong_ban  total_duration
# 0     2020-01-01  wo_co_dien        59856.56
# 7     2020-01-02  wo_co_dien       205396.18
# 8     2020-01-03  wo_co_dien       238813.40
# 14    2020-01-04  wo_co_dien       263309.13
# 19    2020-01-05  wo_co_dien       281805.86
# ...          ...         ...             ...
# 7791  2023-12-27  wo_co_dien          585.66
# 7794  2023-12-28  wo_co_dien          391.99
# 7801  2023-12-29  wo_co_dien          291.98
# 7802  2023-12-30  wo_co_dien          234.24
# 7809  2023-12-31  wo_co_dien          342.89
#
# [1461 rows x 3 columns]
# Phòng ban: wo_ksnn
#             date phong_ban  total_duration
# 2     2020-01-01   wo_ksnn          682.55
# 5     2020-01-02   wo_ksnn         1611.54
# 9     2020-01-03   wo_ksnn         1776.64
# 13    2020-01-04   wo_ksnn         1981.34
# 17    2020-01-05   wo_ksnn         2008.04
# ...          ...       ...             ...
# 7793  2023-12-27   wo_ksnn        79821.50
# 7796  2023-12-28   wo_ksnn        74093.16
# 7799  2023-12-29   wo_ksnn        68523.96
# 7803  2023-12-30   wo_ksnn        62641.27
# 7808  2023-12-31   wo_ksnn        57173.30
#
# [1460 rows x 3 columns]
# Phòng ban: wo_ktts
#             date phong_ban  total_duration
# 26    2020-01-07   wo_ktts            1.73
# 193   2020-02-11   wo_ktts            9.44
# 200   2020-02-12   wo_ktts           24.00
# 207   2020-02-13   wo_ktts           24.00
# 208   2020-02-14   wo_ktts           24.00
# ...          ...       ...             ...
# 7413  2023-09-24   wo_ktts         1584.00
# 7415  2023-09-25   wo_ktts         1584.00
# 7420  2023-09-26   wo_ktts         1584.00
# 7424  2023-09-27   wo_ktts         1584.00
# 7429  2023-09-28   wo_ktts          644.23
#
# [1087 rows x 3 columns]
# Phòng ban: wo_noc
#             date phong_ban  total_duration
# 3     2020-01-01    wo_noc         1825.36
# 4     2020-01-02    wo_noc         4725.20
# 11    2020-01-03    wo_noc         9869.28
# 15    2020-01-04    wo_noc        11700.22
# 16    2020-01-05    wo_noc        13324.29
# ...          ...       ...             ...
# 7792  2023-12-27    wo_noc        11723.09
# 7797  2023-12-28    wo_noc        10208.14
# 7798  2023-12-29    wo_noc        10022.66
# 7805  2023-12-30    wo_noc         9872.19
# 7807  2023-12-31    wo_noc         9844.20
#
# [1461 rows x 3 columns]
# Phòng ban: wo_others
#             date  phong_ban  total_duration
# 1     2020-01-01  wo_others          308.45
# 6     2020-01-02  wo_others         1148.91
# 10    2020-01-03  wo_others         1822.48
# 12    2020-01-04  wo_others         2888.70
# 18    2020-01-05  wo_others         4200.74
# ...          ...        ...             ...
# 7790  2023-12-27  wo_others        59654.00
# 7795  2023-12-28  wo_others        54250.64
# 7800  2023-12-29  wo_others        45523.09
# 7804  2023-12-30  wo_others        33199.07
# 7806  2023-12-31  wo_others        24601.24
#
# [1461 rows x 3 columns]
# Phòng ban: wo_vt_cntt
#             date   phong_ban  total_duration
# 67    2020-01-17  wo_vt_cntt         2895.47
# 73    2020-01-18  wo_vt_cntt         9668.49
# 77    2020-01-19  wo_vt_cntt        16169.80
# 84    2020-01-20  wo_vt_cntt        22020.62
# 88    2020-01-21  wo_vt_cntt        28404.93
# ...          ...         ...             ...
# 7269  2023-08-27  wo_vt_cntt           24.00
# 7273  2023-08-28  wo_vt_cntt           24.00
# 7280  2023-08-29  wo_vt_cntt           24.00
# 7286  2023-08-30  wo_vt_cntt           24.00
# 7291  2023-08-31  wo_vt_cntt            8.25
#
# [880 rows x 3 columns]

# %% [markdown]
# ## save data frame by Phong Ban

# %%
df_wo_co_dien = phong_ban_dict['wo_co_dien']
df_wo_ksnn = phong_ban_dict['wo_ksnn']
df_wo_ktts = phong_ban_dict['wo_ktts']
df_wo_noc = phong_ban_dict['wo_noc']
df_wo_vt_cntt = phong_ban_dict['wo_vt_cntt']
df_wo_others = phong_ban_dict['wo_others']

# %%
df_wo_co_dien
# Out:
#             date   phong_ban  total_duration
# 0     2020-01-01  wo_co_dien        59856.56
# 7     2020-01-02  wo_co_dien       205396.18
# 8     2020-01-03  wo_co_dien       238813.40
# 14    2020-01-04  wo_co_dien       263309.13
# 19    2020-01-05  wo_co_dien       281805.86
# ...          ...         ...             ...
# 7791  2023-12-27  wo_co_dien          585.66
# 7794  2023-12-28  wo_co_dien          391.99
# 7801  2023-12-29  wo_co_dien          291.98
# 7802  2023-12-30  wo_co_dien          234.24
# 7809  2023-12-31  wo_co_dien          342.89
#
# [1461 rows x 3 columns]

# %% [markdown]
# # Training model with Phong Ban : wo_co_dien

# %% [markdown]
# ## Preprocessing data

# %% [markdown]
# ### sum total duration by "day"

# %%
# Nhóm dữ liệu theo ngày và tính tổng thời gian
df_wo_co_dien = df_wo_co_dien.groupby('date')['total_duration'].sum()

# Tạo DataFrame mới từ kết quả
df_wo_co_dien = pd.DataFrame(df_wo_co_dien, columns=['date', 'total_duration'])
df_wo_co_dien.drop('date',axis=1,inplace=True)
df_wo_co_dien
# Out:
#             total_duration
# date
# 2020-01-01        59856.56
# 2020-01-02       205396.18
# 2020-01-03       238813.40
# 2020-01-04       263309.13
# 2020-01-05       281805.86
# ...                    ...
# 2023-12-27          585.66
# 2023-12-28          391.99
# 2023-12-29          291.98
# 2023-12-30          234.24
# 2023-12-31          342.89
#
# [1461 rows x 1 columns]

# %% [markdown]
# ## build model LSTM

# %% [markdown]
# ## Visualize

# %%
plt.plot(df_wo_co_dien.index, df_wo_co_dien['total_duration'], label='total_duration', color='red')
plt.xlabel('day')
plt.ylabel('tota_duration')
plt.title('Biểu đồ wo_co_dien')
plt.legend(loc='best')

# %%
df_wo_co_dien.shape
# Out:
# (1461, 1)

# %%
#chia tập dữ liệu
data = df_wo_co_dien.values
train_data = data[:800]
test_data = data[800:]

# %%
#chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))
sc_train = sc.fit_transform(data)

# %%
#tạo vòng lặp các giá trị
mark = 30
x_train,y_train=[],[]
for i in range(mark,len(train_data)):
  x_train.append(sc_train[i-mark:i,0]) #lấy 50 giá đóng cửa liên tục
  y_train.append(sc_train[i,0]) #lấy ra giá đóng cửa ngày hôm sau

# %%
#xếp dữ liệu thành 1 mảng 2 chiều
x_train = np.array(x_train)
y_train = np.array(y_train)

#xếp lại dữ liệu thành mảng 1 chiều
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
y_train = np.reshape(y_train,(y_train.shape[0],1))

# %%
#xây dựng mô hình
model = Sequential() #tạo lớp mạng cho dữ liệu đầu vào
#2 lớp LSTM
model.add(LSTM(units=128,input_shape=(x_train.shape[1],1),return_sequences=True))
model.add(LSTM(units=64))
model.add(Dropout(0.5)) #loại bỏ 1 số đơn vị tránh học tủ (overfitting)
model.add(Dense(1)) #output đầu ra 1 chiều
#đo sai số tuyệt đối trung bình có sử dụng trình tối ưu hóa adam
model.compile(loss='mean_absolute_error',optimizer='adam')

# %%
#huấn luyện mô hình
save_model = "save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')
model.fit(x_train,y_train,epochs=80,batch_size=50,verbose=2,callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.09945, saving model to save_model.hdf5
# 16/16 - 4s - loss: 0.0994 - 4s/epoch - 253ms/step
# Epoch 2/80
# /home/huydq/anaconda3/envs/vhkt/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: loss improved from 0.09945 to 0.06725, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0672 - 230ms/epoch - 14ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.06725 to 0.06325, saving model to save_model.hdf5
# 16/16 - 1s - loss: 0.0632 - 1s/epoch - 70ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.06325 to 0.05781, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0578 - 259ms/epoch - 16ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.05781 to 0.05646, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0565 - 231ms/epoch - 14ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.05646 to 0.05259, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0526 - 237ms/epoch - 15ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.05259 to 0.05231, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0523 - 232ms/epoch - 14ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.05231 to 0.05131, saving model to save_model.hdf5
# 16/16 - 1s - loss: 0.0513 - 1s/epoch - 65ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.05131 to 0.05036, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0504 - 240ms/epoch - 15ms/step
# Epoch 10/80
#
# Epoch 10: loss improved from 0.05036 to 0.04910, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0491 - 293ms/epoch - 18ms/step
# Epoch 11/80
#
# Epoch 11: loss improved from 0.04910 to 0.04902, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0490 - 242ms/epoch - 15ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.04902 to 0.04572, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0457 - 235ms/epoch - 15ms/step
# Epoch 13/80
#
# Epoch 13: loss improved from 0.04572 to 0.04499, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0450 - 239ms/epoch - 15ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.04499
# 16/16 - 0s - loss: 0.0489 - 223ms/epoch - 14ms/step
# Epoch 15/80
#
# Epoch 15: loss improved from 0.04499 to 0.04388, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0439 - 229ms/epoch - 14ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.04388
# 16/16 - 0s - loss: 0.0452 - 215ms/epoch - 13ms/step
# Epoch 17/80
#
# Epoch 17: loss improved from 0.04388 to 0.04339, saving model to save_model.hdf5
# 16/16 - 1s - loss: 0.0434 - 988ms/epoch - 62ms/step
# Epoch 18/80
#
# Epoch 18: loss improved from 0.04339 to 0.04217, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0422 - 256ms/epoch - 16ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.04217
# 16/16 - 0s - loss: 0.0428 - 221ms/epoch - 14ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.04217
# 16/16 - 0s - loss: 0.0425 - 219ms/epoch - 14ms/step
# Epoch 21/80
#
# Epoch 21: loss improved from 0.04217 to 0.04087, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0409 - 300ms/epoch - 19ms/step
# Epoch 22/80
#
# Epoch 22: loss improved from 0.04087 to 0.03874, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0387 - 234ms/epoch - 15ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.03874
# 16/16 - 0s - loss: 0.0399 - 216ms/epoch - 13ms/step
# Epoch 24/80
#
# Epoch 24: loss improved from 0.03874 to 0.03823, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0382 - 231ms/epoch - 14ms/step
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.03823
# 16/16 - 0s - loss: 0.0395 - 217ms/epoch - 14ms/step
# Epoch 26/80
#
# Epoch 26: loss improved from 0.03823 to 0.03665, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0366 - 229ms/epoch - 14ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.03665
# 16/16 - 0s - loss: 0.0368 - 220ms/epoch - 14ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.03665
# 16/16 - 0s - loss: 0.0369 - 216ms/epoch - 13ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.03665
# 16/16 - 0s - loss: 0.0378 - 216ms/epoch - 14ms/step
# Epoch 30/80
#
# Epoch 30: loss improved from 0.03665 to 0.03365, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0336 - 285ms/epoch - 18ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.03365
# 16/16 - 0s - loss: 0.0367 - 222ms/epoch - 14ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.03365
# 16/16 - 0s - loss: 0.0360 - 222ms/epoch - 14ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.03365
# 16/16 - 0s - loss: 0.0347 - 226ms/epoch - 14ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.03365
# 16/16 - 0s - loss: 0.0356 - 221ms/epoch - 14ms/step
# Epoch 35/80
#
# Epoch 35: loss improved from 0.03365 to 0.03311, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0331 - 227ms/epoch - 14ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.03311
# 16/16 - 0s - loss: 0.0339 - 218ms/epoch - 14ms/step
# Epoch 37/80
#
# Epoch 37: loss improved from 0.03311 to 0.03244, saving model to save_model.hdf5
# 16/16 - 1s - loss: 0.0324 - 691ms/epoch - 43ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.03244
# 16/16 - 0s - loss: 0.0340 - 219ms/epoch - 14ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.03244
# 16/16 - 0s - loss: 0.0336 - 215ms/epoch - 13ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.03244
# 16/16 - 0s - loss: 0.0339 - 216ms/epoch - 13ms/step
# Epoch 41/80
#
# Epoch 41: loss improved from 0.03244 to 0.03167, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0317 - 230ms/epoch - 14ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.03167
# 16/16 - 0s - loss: 0.0324 - 218ms/epoch - 14ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.03167
# 16/16 - 0s - loss: 0.0327 - 219ms/epoch - 14ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.03167
# 16/16 - 0s - loss: 0.0328 - 216ms/epoch - 13ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.03167
# 16/16 - 0s - loss: 0.0335 - 218ms/epoch - 14ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.03167
# 16/16 - 0s - loss: 0.0321 - 215ms/epoch - 13ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.03167
# 16/16 - 0s - loss: 0.0327 - 217ms/epoch - 14ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.03167
# 16/16 - 0s - loss: 0.0317 - 216ms/epoch - 14ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.03167
# 16/16 - 0s - loss: 0.0320 - 215ms/epoch - 13ms/step
# Epoch 50/80
#
# Epoch 50: loss improved from 0.03167 to 0.03119, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0312 - 261ms/epoch - 16ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.03119
# 16/16 - 0s - loss: 0.0316 - 227ms/epoch - 14ms/step
# Epoch 52/80
#
# Epoch 52: loss improved from 0.03119 to 0.03087, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0309 - 240ms/epoch - 15ms/step
# Epoch 53/80
#
# Epoch 53: loss improved from 0.03087 to 0.03026, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0303 - 233ms/epoch - 15ms/step
# Epoch 54/80
#
# Epoch 54: loss improved from 0.03026 to 0.02886, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0289 - 226ms/epoch - 14ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.02886
# 16/16 - 0s - loss: 0.0297 - 217ms/epoch - 14ms/step
# Epoch 56/80
#
# Epoch 56: loss improved from 0.02886 to 0.02826, saving model to save_model.hdf5
# 16/16 - 1s - loss: 0.0283 - 903ms/epoch - 56ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.02826
# 16/16 - 0s - loss: 0.0289 - 222ms/epoch - 14ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.02826
# 16/16 - 0s - loss: 0.0298 - 218ms/epoch - 14ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.02826
# 16/16 - 0s - loss: 0.0290 - 217ms/epoch - 14ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.02826
# 16/16 - 0s - loss: 0.0284 - 216ms/epoch - 14ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.02826
# 16/16 - 0s - loss: 0.0288 - 231ms/epoch - 14ms/step
# Epoch 62/80
#
# Epoch 62: loss improved from 0.02826 to 0.02706, saving model to save_model.hdf5
# 16/16 - 1s - loss: 0.0271 - 869ms/epoch - 54ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0275 - 227ms/epoch - 14ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0273 - 216ms/epoch - 14ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0283 - 216ms/epoch - 14ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0287 - 218ms/epoch - 14ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0284 - 218ms/epoch - 14ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0298 - 214ms/epoch - 13ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0272 - 215ms/epoch - 13ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0272 - 213ms/epoch - 13ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0282 - 222ms/epoch - 14ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0282 - 227ms/epoch - 14ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0282 - 226ms/epoch - 14ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0295 - 230ms/epoch - 14ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0280 - 219ms/epoch - 14ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0271 - 215ms/epoch - 13ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0276 - 218ms/epoch - 14ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0280 - 216ms/epoch - 14ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.02706
# 16/16 - 0s - loss: 0.0288 - 217ms/epoch - 14ms/step
# Epoch 80/80
#
# Epoch 80: loss improved from 0.02706 to 0.02705, saving model to save_model.hdf5
# 16/16 - 0s - loss: 0.0271 - 258ms/epoch - 16ms/step

# %%
#dữ liệu train
y_train = sc.inverse_transform(y_train) #giá thực
final_model = load_model("save_model.hdf5")
y_train_predict = final_model.predict(x_train) #dự đoán giá đóng cửa trên tập đã train
y_train_predict = sc.inverse_transform(y_train_predict) #giá dự đoán
# Out:
# 25/25 [==============================] - 1s 5ms/step

# %%
#xử lý dữ liệu test
test = df_wo_co_dien[len(train_data)-mark:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(mark,test.shape[0]):
  x_test.append(sc_test[i-mark:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[800:] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 21/21 [==============================] - 0s 5ms/step

# %%
#lập biểu đồ so sánh
train_data1 = df_wo_co_dien[mark:800]
test_data1 = df_wo_co_dien[800:]

plt.figure(figsize=(24,8))
plt.plot(df_wo_co_dien,label='Total duration thực tế',color='red') #đường giá thực
train_data1['Dự đoán'] = y_train_predict #thêm dữ liệu
plt.plot(train_data1['Dự đoán'],label='Total duration dự đoán train',color='green') #đường giá dự báo train
test_data1['Dự đoán'] = y_test_predict #thêm dữ liệu
plt.plot(test_data1['Dự đoán'],label='Total duration dự đoán test',color='blue') #đường giá dự báo test
plt.title('So sánh Total duration dự báo và Total duration thực tế') #đặt tên biểu đồ
plt.xlabel('Thời gian') #đặt tên hàm x
plt.ylabel('Total duration') #đặt tên hàm y
plt.legend() #chú thích
plt.show()
# Out:
# /tmp/ipykernel_901040/552498037.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data1['Dự đoán'] = y_train_predict #thêm dữ liệu
# /tmp/ipykernel_901040/552498037.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1['Dự đoán'] = y_test_predict #thêm dữ liệu

# %%
#r2
print('Độ phù hợp tập train:',r2_score(y_train,y_train_predict))
#mae
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):',mean_absolute_error(y_train,y_train_predict))
#mae
print('Phần trăm sai số tuyệt đối trung bình tập train:',mean_absolute_percentage_error(y_train,y_train_predict))
# Out:
# Độ phù hợp tập train: 0.9569983498068771
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 4916.803712129667
# Phần trăm sai số tuyệt đối trung bình tập train: 0.0980548549983062

# %%
train_data1
# Out:
#             total_duration       Dự đoán
# date
# 2020-01-31         8367.17   7476.101074
# 2020-02-01         8269.20   6873.606445
# 2020-02-02        12647.71   6780.375488
# 2020-02-03        14143.91  10448.969727
# 2020-02-04        14860.27  12415.443359
# ...                    ...           ...
# 2022-03-06        33217.83  32661.626953
# 2022-03-07        32343.37  31332.363281
# 2022-03-08        31542.42  30383.583984
# 2022-03-09        30431.50  29548.792969
# 2022-03-10        29489.16  28464.525391
#
# [770 rows x 2 columns]

# %%
#r2
print('Độ phù hợp tập test:',r2_score(y_test,y_test_predict))
#mae
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):',mean_absolute_error(y_test,y_test_predict))
#mae
print('Phần trăm sai số tuyệt đối trung bình tập test:',mean_absolute_percentage_error(y_test,y_test_predict))
# Out:
# Độ phù hợp tập test: 0.9343581389200316
# Sai số tuyệt đối trung bình trên tập test (VNĐ): 2269.2571832815565
# Phần trăm sai số tuyệt đối trung bình tập test: 0.1264776904903641

# %%
test_data1
# Out:
#             total_duration       Dự đoán
# date
# 2022-03-11        29006.62  27500.648438
# 2022-03-12        28100.86  26959.337891
# 2022-03-13        27565.53  26115.597656
# 2022-03-14        27244.67  25546.476562
# 2022-03-15        27150.85  25208.791016
# ...                    ...           ...
# 2023-12-27          585.66   -315.627350
# 2023-12-28          391.99   -448.651031
# 2023-12-29          291.98   -624.133362
# 2023-12-30          234.24   -734.671631
# 2023-12-31          342.89   -796.393921
#
# [661 rows x 2 columns]

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- ---------------
# absl-py                      2.1.0
# anyio                        4.3.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        23.2.0
# Babel                        2.14.0
# beautifulsoup4               4.12.3
# bleach                       6.1.0
# cachetools                   5.3.2
# certifi                      2024.2.2
# cffi                         1.16.0
# charset-normalizer           3.3.2
# comm                         0.2.1
# contourpy                    1.2.0
# cycler                       0.12.1
# debugpy                      1.8.1
# decorator                    5.1.1
# defusedxml                   0.7.1
# et-xmlfile                   1.1.0
# exceptiongroup               1.2.0
# executing                    2.0.1
# fastjsonschema               2.19.1
# flatbuffers                  23.5.26
# fonttools                    4.49.0
# fqdn                         1.5.1
# gast                         0.5.4
# google-auth                  2.28.0
# google-auth-oauthlib         1.2.0
# google-pasta                 0.2.0
# grpcio                       1.60.1
# h11                          0.14.0
# h5py                         3.10.0
# httpcore                     1.0.3
# httpx                        0.26.0
# idna                         3.6
# ipykernel                    6.29.2
# ipython                      8.21.0
# ipywidgets                   8.1.2
# isoduration                  20.11.0
# jedi                         0.19.1
# Jinja2                       3.1.3
# joblib                       1.3.2
# json5                        0.9.17
# jsonpointer                  2.4
# jsonschema                   4.21.1
# jsonschema-specifications    2023.12.1
# jupyter                      1.0.0
# jupyter_client               8.6.0
# jupyter-console              6.6.3
# jupyter_core                 5.7.1
# jupyter-events               0.9.0
# jupyter-lsp                  2.2.2
# jupyter_server               2.12.5
# jupyter_server_terminals     0.5.2
# jupyterlab                   4.1.2
# jupyterlab_pygments          0.3.0
# jupyterlab_server            2.25.3
# jupyterlab_widgets           3.0.10
# keras                        2.15.0
# kiwisolver                   1.4.5
# libclang                     16.0.6
# Markdown                     3.5.2
# MarkupSafe                   2.1.5
# matplotlib                   3.8.3
# matplotlib-inline            0.1.6
# mistune                      3.0.2
# ml-dtypes                    0.2.0
# nbclient                     0.9.0
# nbconvert                    7.16.1
# nbformat                     5.9.2
# nest-asyncio                 1.6.0
# notebook                     7.1.0
# notebook_shim                0.2.4
# numpy                        1.26.4
# oauthlib                     3.2.2
# openpyxl                     3.1.2
# opt-einsum                   3.3.0
# overrides                    7.7.0
# packaging                    23.2
# pandas                       2.2.0
# pandocfilters                1.5.1
# parso                        0.8.3
# pexpect                      4.9.0
# pillow                       10.2.0
# pip                          23.3.1
# platformdirs                 4.2.0
# prometheus_client            0.20.0
# prompt-toolkit               3.0.43
# protobuf                     4.25.3
# psutil                       5.9.8
# ptyprocess                   0.7.0
# pure-eval                    0.2.2
# pyasn1                       0.5.1
# pyasn1-modules               0.3.0
# pycparser                    2.21
# Pygments                     2.17.2
# pyparsing                    3.1.1
# python-dateutil              2.8.2
# python-json-logger           2.0.7
# pytz                         2024.1
# PyYAML                       6.0.1
# pyzmq                        25.1.2
# qtconsole                    5.5.1
# QtPy                         2.4.1
# referencing                  0.33.0
# requests                     2.31.0
# requests-oauthlib            1.3.1
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rpds-py                      0.18.0
# rsa                          4.9
# scikit-learn                 1.4.1.post1
# scipy                        1.12.0
# seaborn                      0.13.2
# Send2Trash                   1.8.2
# setuptools                   68.2.2
# six                          1.16.0
# sniffio                      1.3.0
# soupsieve                    2.5
# stack-data                   0.6.3
# tensorboard                  2.15.2
# tensorboard-data-server      0.7.2
# tensorflow                   2.15.0.post1
# tensorflow-estimator         2.15.0
# tensorflow-io-gcs-filesystem 0.36.0
# termcolor                    2.4.0
# terminado                    0.18.0
# threadpoolctl                3.3.0
# tinycss2                     1.2.1
# tomli                        2.0.1
# tornado                      6.4
# traitlets                    5.14.1
# types-python-dateutil        2.8.19.20240106
# typing_extensions            4.9.0
# tzdata                       2024.1
# uri-template                 1.3.0
# urllib3                      2.2.1
# wcwidth                      0.2.13
# webcolors                    1.13
# webencodings                 0.5.1
# websocket-client             1.7.0
# Werkzeug                     3.0.1
# wheel                        0.41.2
# widgetsnbextension           4.0.10
# wrapt                        1.14.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # future prediction

# %%
# Lấy ngày kế tiếp sau ngày cuối cùng trong tập dữ liệu để dự đoán
next_date = df['Ngày'].iloc[-1] + pd.Timedelta(days=1)

# Chuyển đổi ngày kế tiếp sang dạng datetime
next_date = pd.to_datetime(next_date)

# Lấy giá trị của ngày cuối cùng trong tập dữ liệu
next_closing_price = np.array([df['Đóng cửa'].iloc[-1]])  # Lấy giá trị đóng cửa của ngày cuối cùng

# Chuẩn hóa giá trị của ngày cuối cùng
next_closing_price_normalized = sc.transform(next_closing_price.reshape(-1, 1))  # Chuyển thành mảng 2D

# Tạo dự đoán cho ngày kế tiếp bằng mô hình đã huấn luyện
x_next = np.array([sc_train[-50:, 0]])  # Lấy 50 giá đóng cửa gần nhất
x_next = np.reshape(x_next, (x_next.shape[0], x_next.shape[1], 1))
y_next_predict = final_model.predict(x_next)
y_next_predict = sc.inverse_transform(y_next_predict)

# Thêm dữ liệu dự đoán của ngày kế tiếp vào DataFrame
df_next = pd.DataFrame({'Ngày': [next_date], 'Đóng cửa': [y_next_predict[0][0]]})
df1 = pd.concat([df1, df_next])

# Vẽ biểu đồ mới với dự đoán cho ngày kế tiếp
plt.figure(figsize=(15, 5))
plt.plot(df1['Ngày'], df1['Đóng cửa'], label='Giá thực tế', color='red')
plt.plot(train_data1.index, train_data1['Dự đoán'], label='Giá dự đoán train', color='green')
plt.plot(test_data1.index, test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.scatter([next_date], [y_next_predict[0][0]], color='orange', label='Dự đoán ngày kế tiếp')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.title('So sánh giá dự báo và giá thực tế')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ngày'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-2b1528de55df> in <cell line: 2>()
#       1 # Lấy ngày kế tiếp sau ngày cuối cùng trong tập dữ liệu để dự đoán
# ----> 2 next_date = df['Ngày'].iloc[-1] + pd.Timedelta(days=1)
#       3
#       4 # Chuyển đổi ngày kế tiếp sang dạng datetime
#       5 next_date = pd.to_datetime(next_date)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Ngày'

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 30, 128)           66560
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 116033 (453.25 KB)
# Trainable params: 116033 (453.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
